# %%
print('Hello Jupyter!')
# Out:
# Hello Jupyter!

# %% [markdown]
# __hello__

# %%
x=5

# %%
y=10

# %%
z= x+y

# %%
print("z")
# Out:
# z

# %%
print(z)
# Out:
# 15

# %%
print(x/y)
# Out:
# 0.5

# %%
print(x**y)
# Out:
# 9765625

# %% [markdown]
# ## Exercici 3
#
# [x] crear títols
#
# [x] llistes
#
# [x] canviar l’estil de la lletra
#
# [x] afegir imatges dins del Notebook.
#
# Nivell 2
# []- Exercici 1
# Exporta el Notebook com a pdf i com a html.
#
# Nivell 3
# []- Exercici 1
# Instal·la Nbextensions al Notebook de Jupyter.

# %% [markdown]
# # Título 1

# %% [markdown]
# ## Título2

# %% [markdown]
# *Italico*
# _Italico2_
# **Negrita**
# **Negrita *Italica y Negrita* Fin negrita**

# %% [markdown]
# ## medios_de_transporte
# * coche
# * moto
# * bici

# %% [markdown]
# :)

# %% [markdown]
# ![descarga.jpg](attachment:descarga.jpg)

# %%
a= 3.556
b= "Ejemplo string"

# %% [markdown]
# # Uso de nbextension Python Markdown
# ## (para poner variables en texto Markdown)
#
# Ejemplo de variables dentro de texto Markdown :
#
# a = {{a}}
#
# b = {{b}}

# %% [markdown]
# # Ejemplo de Hinterland activado:
# ![Hynterland.bmp](attachment:Hynterland.bmp)

# %% [markdown]
# # Ejemplo de agrupación de niveles ( Collapsible Headings)

# %% [markdown]
# ## Nivel 2

# %%
x = 8

# %%
z = 7.5

# %% [markdown]
# ## Nivel 2

# %% [markdown]
# ### Funciona el collapsible Heading.....
